# %%
setwd("/mnt/volume1/qyc/")
source("auto-annot/pipelines/cross_validation.R")
source("auto-annot/pipelines/evaluate.R")
source("auto-annot/pipelines/scripts/single_cell_net.R")

# %%
sample_path <- "/mnt/volume1/qyc/data/Inter-dataset/PbmcBench/10Xv2/10Xv2_pbmc1.csv"
dir_path <- dirname(sample_path)

# %%
labels_path <- paste0(dir_path, "/Labels.csv")
  if (!file.exists(labels_path)) {
    labels_path <- paste0(tools::file_path_sans_ext(sample_path), "Labels.csv")
  }

# %%
results_dir <- "/mnt/volume1/qyc/auto-annot/results"
sample_dir <- paste0(results_dir, "/singleCellNet/", sub("\\.csv$", "", basename(sample_path)), "/")
  if (!dir.exists(sample_dir)) {
    dir.create(sample_dir, recursive = TRUE)
  }

# %%
DataPath <- sample_path
LabelsPath <- labels_path
CV_RDataPath <-  paste0(dir_path, "/CV_folds.RData")
OutputDir <- sample_dir
GeneOrderPath <- NULL
NumGenes <- NULL

# %%
Data <- read.csv(DataPath,row.names = 1)
colnames(Data) <- gsub('_','.',colnames(Data), fixed = TRUE)
Labels <- as.matrix(read.csv(LabelsPath))
load(CV_RDataPath)
Labels <- as.vector(Labels[,col_Index])
Data <- Data[Cells_to_Keep,]
Labels <- Labels[Cells_to_Keep]
if(!is.null(GeneOrderPath) & !is.null (NumGenes)){
  GenesOrder = read.csv(GeneOrderPath)
}

# %%
library(singleCellNet)
library(dplyr)
# Out:
# Warning message:
# “package ‘singleCellNet’ was built under R version 4.4.2”
# Loading required package: ggplot2
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.4.3”
# Loading required package: dplyr
#
# Warning message:
# “package ‘dplyr’ was built under R version 4.4.1”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: pheatmap
#
# Warning message:
# “package ‘pheatmap’ was built under R version 4.4.1”
# Loading required package: reshape2
#
# Warning message:
# “package ‘reshape2’ was built under R version 4.4.1”
# Loading required package: cowplot
#
# Warning message:
# “package ‘cowplot’ was built under R version 4.4.1”

# %%
True_Labels_singleCellNet <- list()
Pred_Labels_singleCellNet <- list()
Training_Time_singleCellNet <- list()
Testing_Time_singleCellNet <- list()
Data = t(as.matrix(Data))              # deals also with sparse matrix

# %%
csRenameOrth<-function(
	expQuery,
	expTrain,
	orthTable,
	speciesQuery='human',
	speciesTrain='mouse'){

 	# what genes in the orth table are in the query table?
	rownames(orthTable)<-as.vector(orthTable[,speciesQuery])
	cgenes<-intersect(rownames(expQuery), rownames(orthTable))
	cat("query genes in ortholog table = ",length(cgenes),"\n")

	# of these, which are in training data?
	oTab<- orthTable[cgenes,]
	rownames(oTab) <- as.vector(oTab[,speciesTrain])
	ccGenes<- intersect(rownames(expTrain), rownames(oTab))
	cat("training genes in ortholog table and query data = ",length(ccGenes),"\n")
	# should put a check here for sufficient number of genes 
	oTab<-oTab[ccGenes,]
	qGenes<-as.vector(oTab[,speciesQuery])
	expQuery <- expQuery[qGenes,]
	rownames(expQuery) <- rownames(oTab) 
	expTrain <- expTrain[rownames(oTab),]
	list(expQuery=expQuery, expTrain=expTrain)
}


#' find best pairs
#'
#' find best pairs
#'
#' @param expDat expDat
#' @param cellLabels named vector of cell groups
#'
#' @return vector of pairs
#' 
#' @export
gnrBP<-function(
  expDat,
  cellLabels,
  topX=50){

	ans<-vector()
    myPatternG<-sc_sampR_to_pattern(as.character(cellLabels))
    for(i in seq(length(myPatternG))){
    	cat(i,"\n")
    	xres<-sc_testPattern(myPatternG[[i]], expDat=expDat)
    	tmpAns<-findBestPairs(xres, topX)
    	ans<-append(ans, tmpAns)
    }
    unique(ans)
}


#' @title
#' Find Classifier-Worthy Gene Candidates
#' @description
#' Find classifier-worthy genes for each cancer category to train the classifier
#'
#' @param expDat a matrix of normalized expression data from \code{\link{trans_prop}}
#' @param sampTab a dataframe of the sample table
#' @param dLevel a string indicating the column name in sample table that contains the cancer category
#' @param topX an integer indicating the number of top positive classification genes for each category to select for training. Will also select topX number of negative classification genes.
#' @param dThresh a number representing the detection threshold
#' @param alpha1 a number representing proportion of cells in which a gene must be considered detected (as defined in geneStats)
#' @param alpha2 a number representing lower proportion of cells for genes that must have higher expression level
#' @param mu a number represeting threshold for average expression level of genes passing the lower proportion criteria
#'
#' @return a list containing two lists: a list of classifier worthy genes named 'cgenes' and a list of cancer category named 'grps'
#' @export
findClassyGenes<-function
(expDat,
 sampTab,
 dLevel,
 topX=25,
 dThresh=0,
 alpha1=0.05,
 alpha2=.001,
 mu=2)
{
	if((dLevel %in% colnames(sampTab)) == FALSE) {
    	stop("Please enter the correct column name for sampTab that indicates the categories")
  	}

	if((topX * 2 > nrow(expDat)) == TRUE) {
    	stop(paste0("Please enter a topX value smaller than ", as.integer(nrow(expDat) / 2)))
  	}

	gsTrain<-sc_statTab(expDat, dThresh=dThresh)
	ggenes<-sc_filterGenes(gsTrain, alpha1=alpha1, alpha2=alpha2, mu=mu)
	grps<-as.vector(sampTab[,dLevel])
	names(grps)<-rownames(sampTab)
	xdiff<-gnrAll(expDat[ggenes,], grps)
	cgenes<-lapply(xdiff, getClassGenes, topX=topX)
	cgenes2<-unique(unlist(cgenes))
	list(cgenes=cgenes2, grps=grps, cgenes_list = cgenes)
}

#' @title
#' Find Classy Genes
#' @description
#' Extract genes suitable for training classifier
#' @param diffRes a dataframe with pval, cval, holm, and rownames as the gene names
#' @param topX a number dicataing the number of genes to select for training classifier
#' @param bottom logic if true use the top x genes with - cvals
#'
#' @return a vector of genes that are good for training classifier for that category
getClassGenes<-function(diffRes, topX=25, bottom=TRUE) {
  #exclude NAs
  xi<-which(!is.na(diffRes$cval))
  diffRes<-diffRes[xi,] # exclude the NAs. Select the rows that does not have NAs

  diffRes<-diffRes[order(diffRes$cval, decreasing=TRUE),] #order based on classification value largest to lowest
  ans<-rownames(diffRes[1:topX,]) # get the top 20 genes

  if(bottom){
    ans<-append(ans, rownames( diffRes[nrow(diffRes) - ((topX-1):0),]))
  }

  # get the least differentially expressed genes as house holders
  # sameRes<-diffRes[order(abs(diffRes$cval), decreasing = FALSE), ]
  # ans<-append(ans, rownames(sameRes[1:topX, ]))

  #return
  ans
}

#' find genes higher in a cluster compared to all other cells
#'
#' ind genes higher in a cluster compared to all other cells
#'
#' @param expDat expDat
#' @param cellLabels named vector of cell groups
#'
#' @return list of diffExp data framnes
#' 
#' @export
gnrAll<-function(
  expDat,
  cellLabels){

  myPatternG<-sc_sampR_to_pattern(as.character(cellLabels))
  # sparse matrix?
  if(class(expDat)[1]!='matrix'){
    expTrans = Matrix::t(expDat)
  }
  else{
    expTrans = t(expDat)
  }
  specificSets<-lapply(myPatternG, sc_testPatternTrans, expDat=expTrans)
  cat("Done testing\n")

#  grpOrder<-myGrpSort(cellLabels)

#  specificSets[grpOrder]

  specificSets
}


makePairTab<-function(genes){
	pTab<-t(combn(genes, 2))
	colnames(pTab)<-c("genes1", "genes2")
	pTab<-cbind(pTab, pairName=paste(pTab[,1], "_",pTab[,2], sep=''))
	pTab
}


#' @title
#' Find the best gene pairs for training
#' @description
#' Find the gene pairs that most distinguish a cancer group from the rest
#'
#' @param expDat expDat
#' @param cell_labels named vector, value is grp, name is cell name
#' @param cgenes_list the list of labelled cgenes
#' @param topX number of genepairs for training
#' @param sliceSize the size of the slice for pair transform. Default at 5e3
#' @param quickPairs TRUE if wanting to select the gene pairs in a quick fashion
#'
#' @import parallel
#' @return vector of top gene-pair names
#'
#' @export
ptGetTop <-function(expDat, cell_labels, cgenes_list=NA, topX=50, sliceSize = 5e3, quickPairs = TRUE){
  if(!quickPairs){
    ans<-vector()
    genes<-rownames(expDat)
    
    ncores<-parallel::detectCores() # detect the number of cores in the system
    mcCores<-1
    if(ncores>1){
      mcCores<-ncores - 1
    }
    cat(ncores, "  --> ", mcCores,"\n")
    
    # make a data frame of pairs of genes that will be sliced later
    pairTab<-makePairTab(genes)
    
    if(topX > nrow(pairTab)) {
      stop(paste0("The data set has ", nrow(pairTab), " total combination of gene pairs. Please select a smaller topX."))
    }
    
    # setup tmp ans list of sc_testPattern
    cat("setup ans and make pattern\n")
    grps<-unique(cell_labels)
    myPatternG<-sc_sampR_to_pattern(as.character(cell_labels))
    statList<-list()
    for(grp in grps){
      statList[[grp]]<-data.frame()
    }
    
    # make the pairedDat, and run sc_testPattern
    cat("make pairDat on slice and test\n")
    nPairs = nrow(pairTab)
    cat("nPairs = ",nPairs,"\n")
    str = 1
    stp = min(c(sliceSize, nPairs)) # detect what is smaller the slice size or npairs
    
    while(str <= nPairs){
      if(stp>nPairs){
        stp <- nPairs
      }
      cat(str,"-", stp,"\n")
      tmpTab<-pairTab[str:stp,]
      tmpPdat<-ptSmall(expDat, tmpTab)
      
      if (Sys.info()[['sysname']] == "Windows") {
        tmpAns<-lapply(myPatternG, sc_testPattern, expDat=tmpPdat)
      }
      else {
        tmpAns<-parallel::mclapply(myPatternG, sc_testPattern, expDat=tmpPdat, mc.cores=mcCores) # this code cannot run on windows
      }
      
      for(gi in seq(length(myPatternG))){
        grp<-grps[[gi]]
        statList[[grp]]<-rbind( statList[[grp]],  tmpAns[[grp]])
      }
      
      
      str<-stp+1
      stp<-str + sliceSize - 1
    }
    
    cat("compile results\n")
    for(grp in grps){
      tmpAns<-findBestPairs(statList[[grp]], topX)
      ans<-append(ans, tmpAns)
    }
    return(unique(ans))
    
  }else{
    myPatternG<-sc_sampR_to_pattern(as.character(cell_labels))
    ans<-vector()
    
    for(cct in names(cgenes_list)){
      genes<-cgenes_list[[cct]]
      pairTab<-makePairTab(genes)
      
      nPairs<-nrow(pairTab)
      cat("nPairs = ", nPairs," for ", cct, "\n")
      
      tmpPdat<-ptSmall(expDat, pairTab)
      
      tmpAns<-findBestPairs( sc_testPattern(myPatternG[[cct]], expDat=tmpPdat), topX)
      ans<-append(ans, tmpAns)
    }
    
    return(unique(ans))
  }
}
ptSmall<-function
(expDat,
 pTab){
	npairs = nrow(pTab)
	ans<-matrix(0, nrow=npairs, ncol=ncol(expDat))
	genes1<-as.vector(pTab[,"genes1"])
	genes2<-as.vector(pTab[,"genes2"])

    for(i in seq(nrow(pTab))){
    	#cat(genes1[i], ": ", genes2[i],"\n")
    	ans[i,]<-as.numeric(expDat[genes1[i],]>expDat[genes2[i],]) 
    }
	colnames(ans)<-colnames(expDat)
	rownames(ans)<-as.vector(pTab[,"pairName"])
	ans
}


#' makes complete gene-to-gene comparison
#'
#' @param expDat expDat
#'
#' @return list of list(genes=data frame, expDat=binary matrix)
#'
#' @export
pair_transform<-function # convert to a vector of length = length(vect)^2 - 1 /2
(expDat){
	ngenes<-nrow(expDat)
	genes<-rownames(expDat)
	ans<-matrix(0, nrow=ngenes*(ngenes-1)/2, ncol=ncol(expDat))
	pair_index<-1
	genes1<-vector()
	genes2<-vector()
	for(i in 1:ngenes){
		for(j in 1:ngenes){
			if(j>i){
				genes1<-append(genes1, genes[i])
				genes2<-append(genes2, genes[j])
				ans[pair_index,]<-as.numeric(expDat[i,]>expDat[j,]) 
				pair_index<-pair_index +1
			}
		}
	}
	colnames(ans)<-colnames(expDat)
	tList2 <- list(genes=data.frame(g1=genes1, g2=genes2), tDat=ans)

	pairNames<-paste(tList2[[1]][,1], "_",tList2[[1]][,2], sep='')

	pairDat<-tList2[[2]]
	rownames(pairDat)<-pairNames
	pairDat
}


#' makes complete gene-to-gene comparison
#'
#' @param expDat expDat
#' @param genePairs genePairs
#'
#' @return matrix indicating which gene of a pair is greater
#'
#' @export
query_transform<-function # convert to a vector of length = length(vect)^2 - 1 /2
(expDat,
 genePairs #vector of strings indicating pairs to compare
 ){
	genes<-strsplit(genePairs, "_")
    ans<-matrix(0, nrow=length(genes), ncol=ncol(expDat))
	pair_index<-1
	genes1<-vector()
	genes2<-vector()
	for(i in seq(length(genes))){
		ans[i,]<-as.numeric(expDat[genes[[i]][1],]>expDat[genes[[i]][2],])
	}
	colnames(ans)<-colnames(expDat)
	rownames(ans)<-genePairs
	ans
}

#' finds the best pairs to use
#'
#' @param xdiff xdiff
#' @param n number of pairs
#' @param maxPer indicates the number of pairs that a gene is allowed to be in
#'
#' @return vector of good pairs
#'
#' @export
findBestPairs<-function # find best and diverse set of pairs
(xdiff,
 n=50,
 maxPer=3){
 
 	
 	xdiff<-xdiff[order(xdiff$cval, decreasing=TRUE),]
 	genes<-unique(unlist(strsplit(rownames(xdiff), "_")))
 	countList <- rep(0, length(genes))
 	names(countList) <- genes	

 	i<-0
 	ans<-vector()
 	xdiff_index<-1
 	pair_names<-rownames(xdiff)
 	while(i < n ){
 		tmpAns<-pair_names[xdiff_index]
 		tgp <- unlist(strsplit(tmpAns, "_"))
 		if( (countList[ tgp[1] ] < maxPer) & (countList[ tgp[2] ] < maxPer )){
 			ans<-append(ans, tmpAns)
 			countList[ tgp[1] ] <- countList[ tgp[1] ]+ 1
 			countList[ tgp[2] ] <- countList[ tgp[2] ]+ 1
 			i<-i+1
 		}
 		xdiff_index <- xdiff_index + 1
 	}
 	ans
 }


#' @export
addRandToSampTab<-function(classRes, sampTab, desc, id="cell_name"){
	cNames<-colnames(classRes)
	snames<-rownames(sampTab)

	rnames<-setdiff(cNames, snames)
	cat("number of random samples: ",length(rnames), "\n")

	stNew<-data.frame(rid=rnames, rdesc=rep("rand", length(rnames)))
	stTop<-sampTab[,c(id, desc)]
	colnames(stNew)<-c(id, desc)
	ans<-rbind(stTop, stNew)
	rownames(ans)<-colnames(classRes)
	ans
}

# %%
i <- 1
if(!is.null(GeneOrderPath) & !is.null (NumGenes)){
      DataTrain <- Data[as.vector(GenesOrder[c(1:NumGenes),i])+1,Train_Idx[[i]]]
      DataTest <- Data[as.vector(GenesOrder[c(1:NumGenes),i])+1,Test_Idx[[i]]]
}else{
    DataTrain <- Data[,Train_Idx[[i]]]
    DataTest <- Data[,Test_Idx[[i]]]
}

# %%
start_time <- Sys.time()
cgenes2<-findClassyGenes(DataTrain, data.frame(Annotation = Labels[Train_Idx[[i]]]), "Annotation")
cgenesA<-cgenes2[['cgenes']]
grps<-cgenes2[['grps']]
DataTrain<-as.matrix(DataTrain[cgenesA,])
# Out:
# Done testing

# %%
getTopGenePairs <- function(expr, labels, topX = 50) {
  genes <- rownames(expr)
  gene_pairs <- combn(genes, 2, simplify = FALSE)
  
  scores <- sapply(gene_pairs, function(pair) {
    g1 <- expr[pair[1], ]
    g2 <- expr[pair[2], ]
    sum_expr <- g1 + g2  # 或者可以用 ratio、diff 等其他组合方式
    sum_expr_discrete <- discretize(sum_expr, nbins = 5)
    mutinformation(sum_expr_discrete, as.factor(labels))
  })

  top_idx <- order(scores, decreasing = TRUE)[1:min(topX, length(scores))]
  top_pairs <- gene_pairs[top_idx]
  
  df <- do.call(rbind, lapply(top_pairs, function(p) data.frame(G1 = p[1], G2 = p[2])))
  return(df)
}

# %%
getTopGenePairs <- function(expr, labels, topX = 50, verbose = TRUE) {
  # 自动按 label 分组生成 pattern
  myPatternG <- sc_sampR_to_pattern(as.character(labels))
  genes <- rownames(expr)
  pairTab <- makePairTab(genes)

  ans <- vector()

  for (grp in names(myPatternG)) {
    if (verbose) cat("Processing group:", grp, "\n")
    tmpPdat <- ptSmall(expr, pairTab)

    testRes <- sc_testPattern(myPatternG[[grp]], expDat = tmpPdat)
    topPairs <- findBestPairs(testRes, topX)
    ans <- append(ans, topPairs)
  }

  return(unique(ans))
}

# %%
top_pairs <- getTopGenePairs(DataTrain, grps)
print(top_pairs)
# Out:
# Processing group: CD14+ monocyte
# Processing group: CD16+ monocyte
# Processing group: Plasmacytoid dendritic cell
# Warning message in sqrt(as.numeric(llfit$summary[, 2])):
# “NaNs produced”
# Processing group: B cell
# Processing group: Natural killer cell
# Processing group: Cytotoxic T cell
# Processing group: CD4+ T cell
# Processing group: Megakaryocyte
# Processing group: Dendritic cell
#   [1] "LYZ_RPL30"               "LYZ_RPL23A"
#   [3] "LYZ_RPS25"               "S100A9_RPS26"
#   [5] "S100A9_RPL23A"           "S100A9_RPS21"
#   [7] "S100A8_CD52"             "S100A8_RPS26"
#   [9] "S100A8_RPS21"            "RP11.1143G9.4_IL32"
#  [11] "RP11.1143G9.4_LTB"       "RP11.1143G9.4_ZNF90"
#  [13] "TYROBP_NKG7"             "TYROBP_CCL5"
#  [15] "TYROBP_GNLY"             "S100A6_RPL23A"
#  [17] "S100A12_FCER1A"          "S100A12_IL32"
#  [19] "S100A12_CD1C"            "MAFB_FCGR3A"
#  [21] "CSTA_FCGR3A"             "S100A6_RPS29"
#  [23] "S100A6_RPS25"            "MAFB_CDKN1C"
#  [25] "LST1_IL32"               "CSTA_FCER1A"
#  [27] "CSTA_CDKN1C"             "MAFB_CD79B"
#  [29] "LST1_CD3E"               "AIF1_CD3E"
#  [31] "AIF1_CD3D"               "AIF1_TRBC2"
#  [33] "LST1_TRBC2"              "FTH1_RPS29"
#  [35] "FTH1_RPS27"              "FTH1_RPS18"
#  [37] "CEBPD_NKG7"              "CEBPD_CST7"
#  [39] "SPI1_CD79A"              "SPI1_LTB"
#  [41] "CEBPD_CCL5"              "SPI1_MS4A1"
#  [43] "LGALS2_FCER1A"           "LGALS2_ENHO"
#  [45] "LGALS2_CST7"             "IER3_CD3E"
#  [47] "IER3_CST7"               "IER3_CTSW"
#  [49] "CEBPB_CCL5"              "MARCKS_CD79A"
#  [51] "FCGR3A_CCL5"             "CDKN1C_CD99"
#  [53] "FCGR3A_NKG7"             "CDKN1C_ETS1"
#  [55] "CDKN1C_CD3G"             "FCGR3A_CST7"
#  [57] "LST1_RPS18"              "LST1_RPL18A"
#  [59] "LST1_RPL32"              "HES4_CD99"
#  [61] "HES4_TRBC2"              "HES4_CD3E"
#  [63] "LINC01272_GPX1"          "LINC01272_CD99"
#  [65] "AIF1_RPS25"              "LINC01272_HCST"
#  [67] "AIF1_RPL38"              "AIF1_RPS18"
#  [69] "TCF7L2_IL32"             "TCF7L2_CCL5"
#  [71] "TCF7L2_CD3E"             "MAFB_S100A9"
#  [73] "SPI1_S100A9"             "LYPD2_CD3D"
#  [75] "LYPD2_TRGC2"             "LYPD2_HIST1H2AC"
#  [77] "SPI1_GPX1"               "SPI1_S100A12"
#  [79] "LMO2_GPX1"               "MAFB_S100A12"
#  [81] "MAFB_IER3"               "POU2F2_JUN"
#  [83] "POU2F2_CD79A"            "POU2F2_MS4A1"
#  [85] "CEBPB_IL32"              "CSTA_S100A9"
#  [87] "VASP_IL32"               "VASP_HCST"
#  [89] "CEBPB_ZFP36L2"           "CEBPB_HCST"
#  [91] "TYROBP_RPS26"            "S100A4_RPL32"
#  [93] "FTH1_RPL34"              "C1QA_BANK1"
#  [95] "VASP_CD3E"               "MARCKS_S100A12"
#  [97] "SCT_CD79A"               "SCT_GZMA"
#  [99] "SCT_CTD.2192J16.22"      "ITM2C_CD52"
# [101] "PTPRS_TRBC2"             "PTPRS_EMP3"
# [103] "PTPRS_CD52"              "JCHAIN_CD52"
# [105] "JCHAIN_MT.CYB"           "SMPD3_KLRD1"
# [107] "SMPD3_GZMA"              "SMPD3_TRBC2"
# [109] "JCHAIN_MT.ATP6"          "DERL3_CD79A"
# [111] "CLEC4C_TRBC2"            "CLEC4C_GZMA"
# [113] "CLEC4C_KLRD1"            "DERL3_MS4A1"
# [115] "ITM2C_MT.CYB"            "ASIP_NRGN"
# [117] "ASIP_KLRD1"              "ASIP_SDPR"
# [119] "RP11.117D22.2_CD79B"     "DERL3_CD79B"
# [121] "RP11.117D22.2_MS4A1"     "RP11.117D22.2_CD79A"
# [123] "ITM2C_YBX1"              "PPP1R14B_MT.CYB"
# [125] "IL3RA_CD79B"             "IL3RA_MS4A1"
# [127] "IL3RA_RHOB"              "UGCG_S100A4"
# [129] "UGCG_ZNF302"             "SCN9A_MTRNR2L11"
# [131] "SCN9A_CTD.2090I13.1"     "UGCG_CD3D"
# [133] "PPP1R14B_YBX1"           "PPP1R14B_MT.ATP6"
# [135] "SCN9A_UBE2M"             "GZMB_GNLY"
# [137] "IGKC_NKG7"               "UNC93B1_EMP3"
# [139] "IGKC_GNLY"               "IGKC_LITAF"
# [141] "UNC93B1_ARRB2"           "UNC93B1_EFHD2"
# [143] "SOX4_CCL5"               "FCER1A_RP5.940J5.9"
# [145] "FCER1A_CD1C"             "MAPKAPK2_CST7"
# [147] "CD79A_CD3D"              "CD79A_CD3G"
# [149] "CD79A_CTSW"              "MS4A1_CD3D"
# [151] "MS4A1_CD3G"              "MS4A1_GZMA"
# [153] "IGHD_CD3D"               "IGHD_CD3G"
# [155] "IGHD_GZMA"               "BANK1_GZMA"
# [157] "BANK1_FCER1A"            "BANK1_CTSW"
# [159] "IGKC_CYBA"               "LINC00926_CST7"
# [161] "IGKC_CCL5"               "LINC00926_CCL4"
# [163] "LINC00926_CTSW"          "CD79B_NKG7"
# [165] "CD79B_EFHD2"             "CD79B_ARRB2"
# [167] "HLA.DQB1_GPX1"           "HLA.DQB1_EFHD2"
# [169] "HLA.DQB1_GNAI2"          "VPREB3_GZMB"
# [171] "VPREB3_FCER1A"           "VPREB3_ADGRG1"
# [173] "RALGPS2_CST7"            "RALGPS2_ARRB2"
# [175] "RALGPS2_CD8A"            "TCL1A_GZMB"
# [177] "TCL1A_KLRD1"             "TCL1A_EFHD2"
# [179] "LTB_IL32"                "LTB_S100A4"
# [181] "JCHAIN_GZMB"             "JCHAIN_CST7"
# [183] "JCHAIN_TRGC2"            "GNG7_FCER1A"
# [185] "GNG7_ARRB2"              "GNG7_CKLF"
# [187] "MARCKS_LYZ"              "LTB_CD3E"
# [189] "RP5.887A10.1_GZMH"       "RP5.887A10.1_CD3E"
# [191] "RP5.887A10.1_CD8A"       "JUN_S100A4"
# [193] "KLF2_S100A4"             "MARCKS_TYROBP"
# [195] "MARCKS_S100A9"           "CD7_CD52"
# [197] "GZMB_CD3D"               "GNLY_RPL26"
# [199] "PRF1_CD3D"               "GZMB_CD3G"
# [201] "GZMB_CD8A"               "GNLY_MTRNR2L12"
# [203] "GZMA_CD3D"               "PRF1_CD8A"
# [205] "PRF1_CD3G"               "GZMA_CD3G"
# [207] "CD7_CD3E"                "GNLY_YBX1"
# [209] "GZMA_CD8A"               "CD7_ZFP36L2"
# [211] "NKG7_RPL26"              "FCGR3A_TRGC2"
# [213] "FCGR3A_HLA.DQB1"         "FCGR3A_CH507.513H4.3"
# [215] "FGFBP2_TRBC2"            "FGFBP2_MTRNR2L8"
# [217] "FGFBP2_TRGC2"            "CTSW_TRBC2"
# [219] "CTSW_MTRNR2L12"          "CTSW_YBX1"
# [221] "KLRD1_TRBC2"             "CCL4_TRGC2"
# [223] "KLRD1_CTD.2192J16.22"    "KLRD1_CH507.513H4.3"
# [225] "TYROBP_AIF1"             "CST7_MTRNR2L12"
# [227] "TYROBP_LST1"             "TYROBP_GPX1"
# [229] "CST7_MTRNR2L8"           "CCL4_CH507.513H4.6"
# [231] "CCL4_CTD.2192J16.22"     "HCST_CD52"
# [233] "CST7_PPP2R5C"            "NKG7_YBX1"
# [235] "NKG7_MTRNR2L8"           "CMC1_GPX1"
# [237] "CMC1_CTD.2192J16.22"     "CMC1_FCER1A"
# [239] "MATK_TUBA4A"             "MATK_LINC00987"
# [241] "GZMH_CH507.513H4.3"      "MATK_CH507.513H4.6"
# [243] "GZMH_RP11.3P17.4"        "GZMH_CLU"
# [245] "EFHD2_GPX1"              "CCL5_GPX1"
# [247] "CCL5_YBX1"               "NKG7_GPX1"
# [249] "CCL5_AC009501.4"         "NKG7_AC009501.4"
# [251] "GZMH_GPX1"               "GZMH_CTSZ"
# [253] "GZMH_FCER1A"             "CST7_CTSZ"
# [255] "CST7_FCER1A"             "CST7_NGFRAP1"
# [257] "FGFBP2_CTSZ"             "FGFBP2_SPARC"
# [259] "FGFBP2_HIST1H2AC"        "CD8A_NGFRAP1"
# [261] "CD8A_CTSA"               "CD8A_FCER1A"
# [263] "GZMB_NGFRAP1"            "GZMB_GNG11"
# [265] "GZMB_RHOB"               "GZMA_SPARC"
# [267] "GZMA_CD1C"               "GZMA_F13A1"
# [269] "CTSW_CTSA"               "CTSW_SPARC"
# [271] "CTSW_MAP3K7CL"           "KLRD1_CTSA"
# [273] "KLRD1_RHOB"              "KLRD1_F13A1"
# [275] "IL32_HLA.DQB1"           "IL32_CD79A"
# [277] "IL32_MS4A1"              "PRF1_CD1C"
# [279] "PRF1_ENHO"               "PRF1_F13A1"
# [281] "GNLY_AC009501.4"         "GNLY_MTRNR2L8"
# [283] "TRGC2_CD1C"              "TRGC2_ITGA2B"
# [285] "TRGC2_C6orf25"           "CD3D_EFNA5"
# [287] "CD3D_TBPL2"              "CD3G_ITGA2B"
# [289] "CD3G_ACRBP"              "CD3G_MYL9"
# [291] "CD3D_RP11.346D14.1"      "CD3E_CD79A"
# [293] "CD3E_HLA.DQB1"           "IL32_NKG7"
# [295] "IL32_CCL5"               "CD3E_NKG7"
# [297] "LTB_IGKC"                "CD3E_CCL5"
# [299] "LTB_CD79A"               "LTB_HLA.DQB1"
# [301] "CD3E_GZMH"               "IL32_GNLY"
# [303] "ZFP36L2_NKG7"            "ZFP36L2_CYBA"
# [305] "ZFP36L2_GZMH"            "AES_GZMH"
# [307] "RPS25_CCL5"              "AES_FGFBP2"
# [309] "CD3D_MTRNR2L11"          "CD3D_CH507.513H4.3"
# [311] "RPL36_S100A4"            "AES_CST7"
# [313] "RPL36_MT.CO2"            "ETS1_GNLY"
# [315] "ETS1_FGFBP2"             "CD7_GNLY"
# [317] "RPL12_S100A4"            "ETS1_GZMB"
# [319] "RPS21_CYBA"              "ZNF90_HLA.DQB1"
# [321] "RPL23A_S100A4"           "RPS26_CYBA"
# [323] "MZT2B_FGFBP2"            "CD7_CST7"
# [325] "RPL36_MT.CO3"            "MZT2B_EFHD2"
# [327] "TRBC2_MTRNR2L11"         "TRBC2_CH507.513H4.3"
# [329] "TRBC2_EFNA5"             "ZNF90_EFHD2"
# [331] "CD7_GZMB"                "ZNF90_GZMB"
# [333] "RP11.302B13.5_HLA.DQB1"  "RPS28_MT.CO2"
# [335] "STMN3_CST7"              "RPS26_AIF1"
# [337] "RPS21_ATP5E"             "RPS28_MT.CO3"
# [339] "RPS26_LST1"              "RPL23A_MT.CO2"
# [341] "STMN3_EFHD2"             "RPS21_AIF1"
# [343] "PF4_RPL26"               "PPBP_RPL26"
# [345] "NRGN_RPS12"              "NRGN_RPL30"
# [347] "PF4_YBX1"                "SDPR_RPL26"
# [349] "NRGN_RPL18A"             "PPBP_YBX1"
# [351] "PF4_AC009501.4"          "SDPR_YBX1"
# [353] "SDPR_AC009501.4"         "PPBP_AC009501.4"
# [355] "TUBB1_TRBC2"             "TUBB1_CD3D"
# [357] "GNG11_TRBC2"             "GNG11_CD3D"
# [359] "TUBB1_CTD.2192J16.22"    "GNG11_RP5.940J5.9"
# [361] "HIST1H2AC_TRBC2"         "HIST1H2AC_CD3D"
# [363] "HIST1H2AC_RP5.940J5.9"   "SPARC_LINC00987"
# [365] "SPARC_RP11.346D14.1"     "SPARC_RPL10L"
# [367] "CLU_RPL10L"              "CLU_CTD.2192J16.22"
# [369] "CLU_LINC00987"           "MAP3K7CL_RP5.940J5.9"
# [371] "MAP3K7CL_CTD.2192J16.22" "MAP3K7CL_RPL10L"
# [373] "TREML1_RP11.346D14.1"    "TREML1_ADAMTSL3"
# [375] "TREML1_LINC00987"        "ACRBP_RP11.346D14.1"
# [377] "ACRBP_FCER1A"            "ACRBP_TBPL2"
# [379] "MYL9_ADAMTSL3"           "MYL9_TBPL2"
# [381] "MYL9_RP11.264B14.2"      "CMTM5_FCER1A"
# [383] "CMTM5_CD1C"              "CMTM5_ENHO"
# [385] "GP9_RP11.3P17.4"         "GP9_TBPL2"
# [387] "GP9_FCER1A"              "ITGA2B_ADAMTSL3"
# [389] "ITGA2B_MTRNR2L11"        "C6orf25_MTRNR2L11"
# [391] "ITGA2B_RP11.264B14.2"    "PPDPF_RPL41"
# [393] "FCER1A_CD3D"             "FCER1A_MTRNR2L11"
# [395] "FCER1A_TRBC2"            "ENHO_TBPL2"
# [397] "ENHO_RPL10L"             "ENHO_LINC00987"
# [399] "CD1C_TRBC2"              "CD1C_RPL10L"
# [401] "CD1C_RP11.346D14.1"      "LGALS2_KLF2"
# [403] "LGALS2_IER3"             "HLA.DQB1_RPL38"
# [405] "LGALS2_RHOB"             "HLA.DQB1_CD79B"
# [407] "HLA.DQB1_AC009501.4"     "CTSZ_TRBC2"
# [409] "CTSZ_CD3D"               "SPI1_KLF2"
# [411] "SPI1_MAFB"               "LMO2_LINC01272"
# [413] "AIF1_IL32"               "CTSZ_TUBA4A"
# [415] "LMO2_FCGR3A"             "BASP1_MS4A1"
# [417] "RP11.1143G9.4_S100A8"    "LMO2_RHOB"
# [419] "RP11.1143G9.4_KLF2"      "BASP1_IGHD"
# [421] "BASP1_LINC00926"         "LYZ_MT.ATP6"
# [423] "RP11.1143G9.4_MAFB"      "CSTA_LINC01272"
# [425] "CEBPD_MAFB"              "LYZ_CD52"
# [427] "ITM2C_CD79A"             "LYZ_MT.ND3"
# [429] "CD302_LINC01272"         "CD302_FCGR3A"
# [431] "LST1_JUN"                "CD302_CDKN1C"
# [433] "CEBPD_IL32"              "PPP1R14B_CD3G"
# [435] "CEBPD_S100A12"

# %%
genePairs <- top_pairs

# %%
genePairs <- paste(top_pairs$G1, top_pairs$G2, sep = "_")

# %%
pdTrain<-query_transform(DataTrain[cgenesA, ], genePairs)

# %%
rf<-sc_makeClassifier(pdTrain[genePairs,], genes=genePairs, groups=grps)
end_time <- Sys.time()
Training_Time_singleCellNet[i] <- as.numeric(difftime(end_time,start_time,units = 'secs'))
# Out:
# Number of missing genes  0

# %%
start_time <- Sys.time()
DataTest<-query_transform(DataTest[cgenesA,], genePairs)
classRes <-rf_classPredict(rf, DataTest)
end_time <- Sys.time()
Testing_Time_singleCellNet[i] <- as.numeric(difftime(end_time,start_time,units = 'secs'))

True_Labels_singleCellNet[i] <- list(Labels[Test_Idx[[i]]])
Pred_Labels_singleCellNet[i] <- list((rownames(classRes)[apply(classRes,2,which.max)])[1:length(Test_Idx[[i]])])

# %%
Pred_Labels_singleCellNet
# Out:
# [[1]]
#    [1] "CD14+ monocyte"              "CD14+ monocyte"
#    [3] "CD14+ monocyte"              "CD14+ monocyte"
#    [5] "CD14+ monocyte"              "CD14+ monocyte"
#    [7] "CD14+ monocyte"              "CD14+ monocyte"
#    [9] "CD14+ monocyte"              "CD14+ monocyte"
#   [11] "CD14+ monocyte"              "CD14+ monocyte"
#   [13] "CD14+ monocyte"              "CD14+ monocyte"
#   [15] "CD14+ monocyte"              "CD14+ monocyte"
#   [17] "CD14+ monocyte"              "CD14+ monocyte"
#   [19] "CD14+ monocyte"              "CD14+ monocyte"
#   [21] "CD14+ monocyte"              "CD14+ monocyte"
#   [23] "CD14+ monocyte"              "CD14+ monocyte"
#   [25] "CD14+ monocyte"              "CD14+ monocyte"
#   [27] "CD14+ monocyte"              "CD14+ monocyte"
#   [29] "CD14+ monocyte"              "CD14+ monocyte"
#   [31] "CD14+ monocyte"              "CD14+ monocyte"
#   [33] "CD14+ monocyte"              "CD14+ monocyte"
#   [35] "CD14+ monocyte"              "CD14+ monocyte"
#   [37] "CD14+ monocyte"              "CD14+ monocyte"
#   [39] "CD14+ monocyte"              "CD14+ monocyte"
#   [41] "CD14+ monocyte"              "CD14+ monocyte"
#   [43] "CD14+ monocyte"              "CD14+ monocyte"
#   [45] "CD14+ monocyte"              "CD14+ monocyte"
#   [47] "CD14+ monocyte"              "CD14+ monocyte"
#   [49] "CD14+ monocyte"              "CD14+ monocyte"
#   [51] "CD14+ monocyte"              "CD14+ monocyte"
#   [53] "CD14+ monocyte"              "CD14+ monocyte"
#   [55] "CD14+ monocyte"              "CD14+ monocyte"
#   [57] "CD14+ monocyte"              "CD14+ monocyte"
#   [59] "CD14+ monocyte"              "CD14+ monocyte"
#   [61] "CD14+ monocyte"              "CD14+ monocyte"
#   [63] "CD14+ monocyte"              "CD14+ monocyte"
#   [65] "CD14+ monocyte"              "CD14+ monocyte"
#   [67] "CD14+ monocyte"              "Plasmacytoid dendritic cell"
#   [69] "Plasmacytoid dendritic cell" "Plasmacytoid dendritic cell"
#   [71] "B cell"                      "B cell"
#   [73] "B cell"                      "B cell"
#   [75] "B cell"                      "B cell"
#   [77] "B cell"                      "B cell"
#   [79] "B cell"                      "B cell"
#   [81] "B cell"                      "B cell"
#   [83] "B cell"                      "B cell"
#   [85] "B cell"                      "B cell"
#   [87] "B cell"                      "B cell"
#   [89] "B cell"                      "B cell"
#   [91] "B cell"                      "Cytotoxic T cell"
#   [93] "B cell"                      "B cell"
#   [95] "B cell"                      "B cell"
#   [97] "B cell"                      "B cell"
#   [99] "B cell"                      "B cell"
#  [101] "B cell"                      "B cell"
#  [103] "B cell"                      "B cell"
#  [105] "B cell"                      "B cell"
#  [107] "B cell"                      "B cell"
#  [109] "B cell"                      "B cell"
#  [111] "B cell"                      "B cell"
#  [113] "B cell"                      "B cell"
#  [115] "CD4+ T cell"                 "B cell"
#  [117] "B cell"                      "B cell"
#  [119] "B cell"                      "B cell"
#  [121] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [123] "Cytotoxic T cell"            "Natural killer cell"
#  [125] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [127] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [129] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [131] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [133] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [135] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [137] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [139] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [141] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [143] "Natural killer cell"         "Cytotoxic T cell"
#  [145] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [147] "Cytotoxic T cell"            "Natural killer cell"
#  [149] "Cytotoxic T cell"            "Natural killer cell"
#  [151] "Cytotoxic T cell"            "Natural killer cell"
#  [153] "Cytotoxic T cell"            "Natural killer cell"
#  [155] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [157] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [159] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [161] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [163] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [165] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [167] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [169] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [171] "Cytotoxic T cell"            "Natural killer cell"
#  [173] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [175] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [177] "Cytotoxic T cell"            "Natural killer cell"
#  [179] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [181] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [183] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [185] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [187] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [189] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [191] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [193] "Natural killer cell"         "Natural killer cell"
#  [195] "Cytotoxic T cell"            "Natural killer cell"
#  [197] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [199] "Cytotoxic T cell"            "Natural killer cell"
#  [201] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [203] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [205] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [207] "Cytotoxic T cell"            "Natural killer cell"
#  [209] "Cytotoxic T cell"            "Natural killer cell"
#  [211] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [213] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [215] "Cytotoxic T cell"            "Natural killer cell"
#  [217] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [219] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [221] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [223] "Natural killer cell"         "Cytotoxic T cell"
#  [225] "Natural killer cell"         "Cytotoxic T cell"
#  [227] "Cytotoxic T cell"            "Natural killer cell"
#  [229] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [231] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [233] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [235] "Natural killer cell"         "Natural killer cell"
#  [237] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [239] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [241] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [243] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [245] "Cytotoxic T cell"            "Natural killer cell"
#  [247] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [249] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [251] "Natural killer cell"         "Cytotoxic T cell"
#  [253] "Cytotoxic T cell"            "Natural killer cell"
#  [255] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [257] "Cytotoxic T cell"            "Natural killer cell"
#  [259] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [261] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [263] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [265] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [267] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [269] "Natural killer cell"         "Cytotoxic T cell"
#  [271] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [273] "Cytotoxic T cell"            "Natural killer cell"
#  [275] "Natural killer cell"         "Cytotoxic T cell"
#  [277] "Cytotoxic T cell"            "CD4+ T cell"
#  [279] "Cytotoxic T cell"            "CD4+ T cell"
#  [281] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [283] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [285] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [287] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [289] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [291] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [293] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [295] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [297] "Cytotoxic T cell"            "CD4+ T cell"
#  [299] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [301] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [303] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [305] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [307] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [309] "CD4+ T cell"                 "CD4+ T cell"
#  [311] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [313] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [315] "Natural killer cell"         "Cytotoxic T cell"
#  [317] "Natural killer cell"         "CD4+ T cell"
#  [319] "Cytotoxic T cell"            "Natural killer cell"
#  [321] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [323] "Cytotoxic T cell"            "CD4+ T cell"
#  [325] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [327] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [329] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [331] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [333] "Cytotoxic T cell"            "CD4+ T cell"
#  [335] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [337] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [339] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [341] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [343] "CD4+ T cell"                 "Cytotoxic T cell"
#  [345] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [347] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [349] "Cytotoxic T cell"            "CD4+ T cell"
#  [351] "Cytotoxic T cell"            "CD4+ T cell"
#  [353] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [355] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [357] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [359] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [361] "Natural killer cell"         "CD4+ T cell"
#  [363] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [365] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [367] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [369] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [371] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [373] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [375] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [377] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [379] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [381] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [383] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [385] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [387] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [389] "CD14+ monocyte"              "CD16+ monocyte"
#  [391] "CD16+ monocyte"              "CD16+ monocyte"
#  [393] "CD16+ monocyte"              "CD16+ monocyte"
#  [395] "CD14+ monocyte"              "CD16+ monocyte"
#  [397] "CD16+ monocyte"              "Cytotoxic T cell"
#  [399] "CD14+ monocyte"              "CD16+ monocyte"
#  [401] "CD16+ monocyte"              "CD16+ monocyte"
#  [403] "CD16+ monocyte"              "CD16+ monocyte"
#  [405] "CD16+ monocyte"              "CD16+ monocyte"
#  [407] "CD16+ monocyte"              "CD14+ monocyte"
#  [409] "CD16+ monocyte"              "CD4+ T cell"
#  [411] "CD4+ T cell"                 "CD4+ T cell"
#  [413] "CD4+ T cell"                 "CD4+ T cell"
#  [415] "CD4+ T cell"                 "CD4+ T cell"
#  [417] "CD4+ T cell"                 "CD4+ T cell"
#  [419] "CD4+ T cell"                 "CD4+ T cell"
#  [421] "CD4+ T cell"                 "CD4+ T cell"
#  [423] "CD4+ T cell"                 "CD4+ T cell"
#  [425] "CD4+ T cell"                 "CD4+ T cell"
#  [427] "CD4+ T cell"                 "CD4+ T cell"
#  [429] "CD4+ T cell"                 "CD4+ T cell"
#  [431] "CD4+ T cell"                 "CD4+ T cell"
#  [433] "CD4+ T cell"                 "CD4+ T cell"
#  [435] "CD4+ T cell"                 "CD4+ T cell"
#  [437] "CD4+ T cell"                 "CD4+ T cell"
#  [439] "CD4+ T cell"                 "Cytotoxic T cell"
#  [441] "CD4+ T cell"                 "CD4+ T cell"
#  [443] "CD4+ T cell"                 "CD4+ T cell"
#  [445] "CD4+ T cell"                 "CD4+ T cell"
#  [447] "CD4+ T cell"                 "CD4+ T cell"
#  [449] "CD4+ T cell"                 "CD4+ T cell"
#  [451] "CD4+ T cell"                 "CD4+ T cell"
#  [453] "CD4+ T cell"                 "CD4+ T cell"
#  [455] "CD4+ T cell"                 "CD4+ T cell"
#  [457] "CD4+ T cell"                 "CD4+ T cell"
#  [459] "CD4+ T cell"                 "CD4+ T cell"
#  [461] "Cytotoxic T cell"            "CD4+ T cell"
#  [463] "CD4+ T cell"                 "CD4+ T cell"
#  [465] "CD4+ T cell"                 "CD4+ T cell"
#  [467] "CD4+ T cell"                 "CD4+ T cell"
#  [469] "CD4+ T cell"                 "CD4+ T cell"
#  [471] "CD4+ T cell"                 "CD4+ T cell"
#  [473] "CD4+ T cell"                 "CD4+ T cell"
#  [475] "CD4+ T cell"                 "CD4+ T cell"
#  [477] "CD4+ T cell"                 "CD4+ T cell"
#  [479] "CD4+ T cell"                 "CD4+ T cell"
#  [481] "CD4+ T cell"                 "CD4+ T cell"
#  [483] "CD4+ T cell"                 "CD4+ T cell"
#  [485] "CD4+ T cell"                 "CD4+ T cell"
#  [487] "Cytotoxic T cell"            "CD4+ T cell"
#  [489] "CD4+ T cell"                 "CD4+ T cell"
#  [491] "Cytotoxic T cell"            "CD4+ T cell"
#  [493] "CD4+ T cell"                 "CD4+ T cell"
#  [495] "CD4+ T cell"                 "CD4+ T cell"
#  [497] "CD4+ T cell"                 "CD4+ T cell"
#  [499] "CD4+ T cell"                 "CD4+ T cell"
#  [501] "CD4+ T cell"                 "CD4+ T cell"
#  [503] "CD4+ T cell"                 "CD4+ T cell"
#  [505] "CD4+ T cell"                 "CD4+ T cell"
#  [507] "CD4+ T cell"                 "Megakaryocyte"
#  [509] "Megakaryocyte"               "Megakaryocyte"
#  [511] "Megakaryocyte"               "Megakaryocyte"
#  [513] "Megakaryocyte"               "Megakaryocyte"
#  [515] "Megakaryocyte"               "Megakaryocyte"
#  [517] "Megakaryocyte"               "Megakaryocyte"
#  [519] "Megakaryocyte"               "Megakaryocyte"
#  [521] "Megakaryocyte"               "Megakaryocyte"
#  [523] "Megakaryocyte"               "Megakaryocyte"
#  [525] "Megakaryocyte"               "Megakaryocyte"
#  [527] "Megakaryocyte"               "Megakaryocyte"
#  [529] "Megakaryocyte"               "Megakaryocyte"
#  [531] "Megakaryocyte"               "Megakaryocyte"
#  [533] "Megakaryocyte"               "Megakaryocyte"
#  [535] "Megakaryocyte"               "Megakaryocyte"
#  [537] "Megakaryocyte"               "Megakaryocyte"
#  [539] "Megakaryocyte"               "Megakaryocyte"
#  [541] "Megakaryocyte"               "Megakaryocyte"
#  [543] "Megakaryocyte"               "Megakaryocyte"
#  [545] "Megakaryocyte"               "Megakaryocyte"
#  [547] "Megakaryocyte"               "Megakaryocyte"
#  [549] "Megakaryocyte"               "Megakaryocyte"
#  [551] "Megakaryocyte"               "Megakaryocyte"
#  [553] "Megakaryocyte"               "Megakaryocyte"
#  [555] "Megakaryocyte"               "Megakaryocyte"
#  [557] "Megakaryocyte"               "CD14+ monocyte"
#  [559] "CD14+ monocyte"              "CD14+ monocyte"
#  [561] "CD14+ monocyte"              "CD14+ monocyte"
#  [563] "CD14+ monocyte"              "CD14+ monocyte"
#  [565] "CD14+ monocyte"              "CD14+ monocyte"
#  [567] "CD14+ monocyte"              "CD14+ monocyte"
#  [569] "CD14+ monocyte"              "CD14+ monocyte"
#  [571] "CD14+ monocyte"              "CD14+ monocyte"
#  [573] "CD14+ monocyte"              "CD14+ monocyte"
#  [575] "CD14+ monocyte"              "CD14+ monocyte"
#  [577] "CD14+ monocyte"              "CD14+ monocyte"
#  [579] "CD14+ monocyte"              "CD14+ monocyte"
#  [581] "CD14+ monocyte"              "CD14+ monocyte"
#  [583] "CD14+ monocyte"              "CD14+ monocyte"
#  [585] "CD14+ monocyte"              "CD14+ monocyte"
#  [587] "CD14+ monocyte"              "CD14+ monocyte"
#  [589] "CD14+ monocyte"              "CD14+ monocyte"
#  [591] "CD14+ monocyte"              "CD14+ monocyte"
#  [593] "CD14+ monocyte"              "CD14+ monocyte"
#  [595] "CD14+ monocyte"              "CD14+ monocyte"
#  [597] "CD14+ monocyte"              "CD14+ monocyte"
#  [599] "CD14+ monocyte"              "CD14+ monocyte"
#  [601] "CD14+ monocyte"              "CD14+ monocyte"
#  [603] "CD14+ monocyte"              "CD14+ monocyte"
#  [605] "CD14+ monocyte"              "CD14+ monocyte"
#  [607] "CD14+ monocyte"              "CD14+ monocyte"
#  [609] "CD14+ monocyte"              "CD14+ monocyte"
#  [611] "CD14+ monocyte"              "CD14+ monocyte"
#  [613] "CD14+ monocyte"              "CD14+ monocyte"
#  [615] "Dendritic cell"              "Dendritic cell"
#  [617] "Dendritic cell"              "Dendritic cell"
#  [619] "Dendritic cell"              "Dendritic cell"
#  [621] "Dendritic cell"              "Dendritic cell"
#  [623] "Dendritic cell"              "Dendritic cell"
#  [625] "Dendritic cell"              "Cytotoxic T cell"
#  [627] "CD4+ T cell"                 "Cytotoxic T cell"
#  [629] "B cell"                      "B cell"
#  [631] "B cell"                      "B cell"
#  [633] "B cell"                      "Plasmacytoid dendritic cell"
#  [635] "B cell"                      "B cell"
#  [637] "B cell"                      "B cell"
#  [639] "B cell"                      "B cell"
#  [641] "B cell"                      "B cell"
#  [643] "B cell"                      "B cell"
#  [645] "B cell"                      "B cell"
#  [647] "B cell"                      "B cell"
#  [649] "B cell"                      "B cell"
#  [651] "Cytotoxic T cell"            "B cell"
#  [653] "B cell"                      "B cell"
#  [655] "B cell"                      "B cell"
#  [657] "B cell"                      "B cell"
#  [659] "B cell"                      "B cell"
#  [661] "B cell"                      "B cell"
#  [663] "B cell"                      "B cell"
#  [665] "B cell"                      "B cell"
#  [667] "B cell"                      "B cell"
#  [669] "B cell"                      "B cell"
#  [671] "B cell"                      "B cell"
#  [673] "B cell"                      "B cell"
#  [675] "B cell"                      "B cell"
#  [677] "B cell"                      "B cell"
#  [679] "B cell"                      "B cell"
#  [681] "B cell"                      "B cell"
#  [683] "B cell"                      "B cell"
#  [685] "B cell"                      "B cell"
#  [687] "B cell"                      "B cell"
#  [689] "B cell"                      "B cell"
#  [691] "Natural killer cell"         "B cell"
#  [693] "B cell"                      "B cell"
#  [695] "B cell"                      "B cell"
#  [697] "B cell"                      "B cell"
#  [699] "B cell"                      "B cell"
#  [701] "B cell"                      "B cell"
#  [703] "B cell"                      "Plasmacytoid dendritic cell"
#  [705] "B cell"                      "B cell"
#  [707] "Cytotoxic T cell"            "CD4+ T cell"
#  [709] "CD4+ T cell"                 "CD4+ T cell"
#  [711] "Cytotoxic T cell"            "CD4+ T cell"
#  [713] "CD4+ T cell"                 "CD4+ T cell"
#  [715] "CD4+ T cell"                 "CD4+ T cell"
#  [717] "Cytotoxic T cell"            "CD4+ T cell"
#  [719] "CD4+ T cell"                 "CD4+ T cell"
#  [721] "CD4+ T cell"                 "CD4+ T cell"
#  [723] "CD4+ T cell"                 "Cytotoxic T cell"
#  [725] "CD4+ T cell"                 "CD4+ T cell"
#  [727] "Cytotoxic T cell"            "CD4+ T cell"
#  [729] "CD4+ T cell"                 "CD4+ T cell"
#  [731] "Cytotoxic T cell"            "CD4+ T cell"
#  [733] "CD4+ T cell"                 "CD4+ T cell"
#  [735] "CD4+ T cell"                 "CD4+ T cell"
#  [737] "CD4+ T cell"                 "Cytotoxic T cell"
#  [739] "CD4+ T cell"                 "CD4+ T cell"
#  [741] "CD4+ T cell"                 "CD4+ T cell"
#  [743] "CD4+ T cell"                 "CD4+ T cell"
#  [745] "CD4+ T cell"                 "CD4+ T cell"
#  [747] "CD4+ T cell"                 "CD4+ T cell"
#  [749] "CD4+ T cell"                 "Natural killer cell"
#  [751] "CD4+ T cell"                 "CD4+ T cell"
#  [753] "CD4+ T cell"                 "Cytotoxic T cell"
#  [755] "CD4+ T cell"                 "CD4+ T cell"
#  [757] "CD4+ T cell"                 "CD4+ T cell"
#  [759] "CD4+ T cell"                 "CD4+ T cell"
#  [761] "CD4+ T cell"                 "CD4+ T cell"
#  [763] "CD4+ T cell"                 "Cytotoxic T cell"
#  [765] "CD4+ T cell"                 "CD4+ T cell"
#  [767] "CD4+ T cell"                 "Cytotoxic T cell"
#  [769] "CD4+ T cell"                 "CD4+ T cell"
#  [771] "CD4+ T cell"                 "CD4+ T cell"
#  [773] "CD4+ T cell"                 "CD4+ T cell"
#  [775] "CD4+ T cell"                 "CD4+ T cell"
#  [777] "CD4+ T cell"                 "CD4+ T cell"
#  [779] "CD4+ T cell"                 "CD4+ T cell"
#  [781] "CD4+ T cell"                 "CD4+ T cell"
#  [783] "CD4+ T cell"                 "CD4+ T cell"
#  [785] "Cytotoxic T cell"            "CD4+ T cell"
#  [787] "CD4+ T cell"                 "CD4+ T cell"
#  [789] "CD4+ T cell"                 "CD4+ T cell"
#  [791] "CD4+ T cell"                 "CD4+ T cell"
#  [793] "CD4+ T cell"                 "Cytotoxic T cell"
#  [795] "CD4+ T cell"                 "CD4+ T cell"
#  [797] "CD4+ T cell"                 "CD4+ T cell"
#  [799] "CD4+ T cell"                 "CD4+ T cell"
#  [801] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [803] "CD4+ T cell"                 "Cytotoxic T cell"
#  [805] "CD4+ T cell"                 "CD4+ T cell"
#  [807] "CD4+ T cell"                 "CD4+ T cell"
#  [809] "CD4+ T cell"                 "Cytotoxic T cell"
#  [811] "CD4+ T cell"                 "CD4+ T cell"
#  [813] "Natural killer cell"         "Cytotoxic T cell"
#  [815] "CD4+ T cell"                 "Cytotoxic T cell"
#  [817] "CD4+ T cell"                 "CD4+ T cell"
#  [819] "Cytotoxic T cell"            "CD4+ T cell"
#  [821] "CD4+ T cell"                 "CD4+ T cell"
#  [823] "CD4+ T cell"                 "Cytotoxic T cell"
#  [825] "CD4+ T cell"                 "CD4+ T cell"
#  [827] "CD4+ T cell"                 "CD4+ T cell"
#  [829] "CD4+ T cell"                 "CD4+ T cell"
#  [831] "CD4+ T cell"                 "CD4+ T cell"
#  [833] "CD4+ T cell"                 "CD4+ T cell"
#  [835] "CD4+ T cell"                 "CD4+ T cell"
#  [837] "CD4+ T cell"                 "CD4+ T cell"
#  [839] "Natural killer cell"         "Cytotoxic T cell"
#  [841] "Natural killer cell"         "Cytotoxic T cell"
#  [843] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [845] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [847] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [849] "Natural killer cell"         "Cytotoxic T cell"
#  [851] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [853] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [855] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [857] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [859] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [861] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [863] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [865] "Cytotoxic T cell"            "Natural killer cell"
#  [867] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [869] "Natural killer cell"         "Cytotoxic T cell"
#  [871] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [873] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [875] "Natural killer cell"         "Cytotoxic T cell"
#  [877] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [879] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [881] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [883] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [885] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [887] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [889] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [891] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [893] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [895] "Natural killer cell"         "Cytotoxic T cell"
#  [897] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [899] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [901] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [903] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [905] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [907] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [909] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [911] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [913] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [915] "Cytotoxic T cell"            "Natural killer cell"
#  [917] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [919] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [921] "Cytotoxic T cell"            "Natural killer cell"
#  [923] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [925] "Natural killer cell"         "Cytotoxic T cell"
#  [927] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [929] "Cytotoxic T cell"            "Natural killer cell"
#  [931] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [933] "Natural killer cell"         "Cytotoxic T cell"
#  [935] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [937] "Natural killer cell"         "Cytotoxic T cell"
#  [939] "Natural killer cell"         "Cytotoxic T cell"
#  [941] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [943] "Natural killer cell"         "Cytotoxic T cell"
#  [945] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [947] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [949] "Cytotoxic T cell"            "Natural killer cell"
#  [951] "Natural killer cell"         "Cytotoxic T cell"
#  [953] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [955] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [957] "Natural killer cell"         "Cytotoxic T cell"
#  [959] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [961] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [963] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [965] "Cytotoxic T cell"            "Natural killer cell"
#  [967] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [969] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [971] "Cytotoxic T cell"            "Natural killer cell"
#  [973] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [975] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [977] "Cytotoxic T cell"            "CD14+ monocyte"
#  [979] "Natural killer cell"         "Cytotoxic T cell"
#  [981] "Natural killer cell"         "Cytotoxic T cell"
#  [983] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [985] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [987] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [989] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [991] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [993] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [995] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [997] "Cytotoxic T cell"            "Cytotoxic T cell"
#  [999] "Cytotoxic T cell"            "Natural killer cell"
# [1001] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1003] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1005] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1007] "Cytotoxic T cell"            "Natural killer cell"
# [1009] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1011] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1013] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1015] "Cytotoxic T cell"            "CD4+ T cell"
# [1017] "Cytotoxic T cell"            "Natural killer cell"
# [1019] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1021] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1023] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1025] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1027] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1029] "Natural killer cell"         "Cytotoxic T cell"
# [1031] "Natural killer cell"         "Natural killer cell"
# [1033] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1035] "Natural killer cell"         "Cytotoxic T cell"
# [1037] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1039] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1041] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1043] "Cytotoxic T cell"            "Natural killer cell"
# [1045] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1047] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1049] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1051] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1053] "Natural killer cell"         "Cytotoxic T cell"
# [1055] "Natural killer cell"         "Cytotoxic T cell"
# [1057] "Natural killer cell"         "Cytotoxic T cell"
# [1059] "Cytotoxic T cell"            "Natural killer cell"
# [1061] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1063] "Cytotoxic T cell"            "Natural killer cell"
# [1065] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1067] "Cytotoxic T cell"            "Natural killer cell"
# [1069] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1071] "Natural killer cell"         "CD4+ T cell"
# [1073] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1075] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1077] "Natural killer cell"         "Cytotoxic T cell"
# [1079] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1081] "Natural killer cell"         "Natural killer cell"
# [1083] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1085] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1087] "Natural killer cell"         "Cytotoxic T cell"
# [1089] "Natural killer cell"         "Cytotoxic T cell"
# [1091] "Megakaryocyte"               "Megakaryocyte"
# [1093] "Megakaryocyte"               "Megakaryocyte"
# [1095] "Megakaryocyte"               "Megakaryocyte"
# [1097] "Megakaryocyte"               "Megakaryocyte"
# [1099] "Megakaryocyte"               "Megakaryocyte"
# [1101] "Megakaryocyte"               "Megakaryocyte"
# [1103] "CD14+ monocyte"              "Megakaryocyte"
# [1105] "CD14+ monocyte"              "Megakaryocyte"
# [1107] "Megakaryocyte"               "Megakaryocyte"
# [1109] "Megakaryocyte"               "Megakaryocyte"
# [1111] "Megakaryocyte"               "Megakaryocyte"
# [1113] "Megakaryocyte"               "Megakaryocyte"
# [1115] "Megakaryocyte"               "Megakaryocyte"
# [1117] "Megakaryocyte"               "CD14+ monocyte"
# [1119] "Megakaryocyte"               "Megakaryocyte"
# [1121] "Megakaryocyte"               "Megakaryocyte"
# [1123] "Megakaryocyte"               "Megakaryocyte"
# [1125] "CD14+ monocyte"              "Megakaryocyte"
# [1127] "Megakaryocyte"               "Megakaryocyte"
# [1129] "Megakaryocyte"               "Megakaryocyte"
# [1131] "CD14+ monocyte"              "CD14+ monocyte"
# [1133] "CD14+ monocyte"              "CD14+ monocyte"
# [1135] "CD14+ monocyte"              "CD14+ monocyte"
# [1137] "CD14+ monocyte"              "CD14+ monocyte"
# [1139] "CD14+ monocyte"              "CD14+ monocyte"
# [1141] "CD14+ monocyte"              "CD14+ monocyte"
# [1143] "CD14+ monocyte"              "CD14+ monocyte"
# [1145] "CD14+ monocyte"              "CD14+ monocyte"
# [1147] "CD14+ monocyte"              "CD14+ monocyte"
# [1149] "CD14+ monocyte"              "CD14+ monocyte"
# [1151] "CD14+ monocyte"              "CD14+ monocyte"
# [1153] "CD14+ monocyte"              "CD14+ monocyte"
# [1155] "CD14+ monocyte"              "CD14+ monocyte"
# [1157] "CD14+ monocyte"              "CD14+ monocyte"
# [1159] "CD14+ monocyte"              "CD14+ monocyte"
# [1161] "CD14+ monocyte"              "CD14+ monocyte"
# [1163] "CD14+ monocyte"              "CD14+ monocyte"
# [1165] "CD14+ monocyte"              "CD14+ monocyte"
# [1167] "CD14+ monocyte"              "CD14+ monocyte"
# [1169] "CD14+ monocyte"              "CD14+ monocyte"
# [1171] "CD14+ monocyte"              "CD14+ monocyte"
# [1173] "CD14+ monocyte"              "CD14+ monocyte"
# [1175] "CD14+ monocyte"              "CD14+ monocyte"
# [1177] "CD14+ monocyte"              "CD14+ monocyte"
# [1179] "CD14+ monocyte"              "CD14+ monocyte"
# [1181] "CD14+ monocyte"              "CD14+ monocyte"
# [1183] "CD14+ monocyte"              "CD14+ monocyte"
# [1185] "CD14+ monocyte"              "CD14+ monocyte"
# [1187] "CD14+ monocyte"              "CD14+ monocyte"
# [1189] "CD14+ monocyte"              "CD14+ monocyte"
# [1191] "CD14+ monocyte"              "CD14+ monocyte"
# [1193] "CD14+ monocyte"              "CD14+ monocyte"
# [1195] "CD14+ monocyte"              "CD14+ monocyte"
# [1197] "CD14+ monocyte"              "CD14+ monocyte"
# [1199] "CD14+ monocyte"              "CD14+ monocyte"
# [1201] "CD14+ monocyte"              "CD4+ T cell"
# [1203] "CD4+ T cell"                 "CD4+ T cell"
# [1205] "CD4+ T cell"                 "CD4+ T cell"
# [1207] "CD4+ T cell"                 "CD4+ T cell"
# [1209] "CD4+ T cell"                 "CD4+ T cell"
# [1211] "CD4+ T cell"                 "CD4+ T cell"
# [1213] "CD4+ T cell"                 "CD4+ T cell"
# [1215] "CD4+ T cell"                 "CD4+ T cell"
# [1217] "CD4+ T cell"                 "CD4+ T cell"
# [1219] "CD4+ T cell"                 "CD4+ T cell"
# [1221] "CD4+ T cell"                 "CD4+ T cell"
# [1223] "CD4+ T cell"                 "CD4+ T cell"
# [1225] "CD4+ T cell"                 "CD4+ T cell"
# [1227] "CD4+ T cell"                 "CD4+ T cell"
# [1229] "CD4+ T cell"                 "CD4+ T cell"
# [1231] "CD4+ T cell"                 "CD4+ T cell"
# [1233] "CD4+ T cell"                 "CD4+ T cell"
# [1235] "CD4+ T cell"                 "CD4+ T cell"
# [1237] "CD4+ T cell"                 "CD4+ T cell"
# [1239] "CD4+ T cell"                 "CD4+ T cell"
# [1241] "CD4+ T cell"                 "CD4+ T cell"
# [1243] "CD4+ T cell"                 "CD4+ T cell"
# [1245] "CD4+ T cell"                 "CD4+ T cell"
# [1247] "CD4+ T cell"                 "CD4+ T cell"
# [1249] "CD4+ T cell"                 "Cytotoxic T cell"
# [1251] "CD4+ T cell"                 "CD4+ T cell"
# [1253] "CD16+ monocyte"              "CD16+ monocyte"
# [1255] "CD16+ monocyte"              "CD16+ monocyte"
# [1257] "CD16+ monocyte"              "CD16+ monocyte"
# [1259] "CD16+ monocyte"              "CD16+ monocyte"
# [1261] "Dendritic cell"              "CD14+ monocyte"
# [1263] "Dendritic cell"              "CD14+ monocyte"
# [1265] "Dendritic cell"              "Dendritic cell"
# [1267] "Dendritic cell"              "Dendritic cell"
# [1269] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1271] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1273] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1275] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1277] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1279] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1281] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1283] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1285] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1287] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1289] "Cytotoxic T cell"            "CD4+ T cell"
# [1291] "CD4+ T cell"                 "Cytotoxic T cell"
# [1293] "Cytotoxic T cell"            "CD4+ T cell"
# [1295] "CD4+ T cell"                 "Cytotoxic T cell"
# [1297] "Cytotoxic T cell"            "CD4+ T cell"
# [1299] "CD4+ T cell"                 "Cytotoxic T cell"
# [1301] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1303] "CD4+ T cell"                 "CD4+ T cell"
# [1305] "CD4+ T cell"                 "CD4+ T cell"
# [1307] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1309] "CD14+ monocyte"              "CD14+ monocyte"
# [1311] "CD14+ monocyte"              "Plasmacytoid dendritic cell"
# [1313] "CD14+ monocyte"              "B cell"
# [1315] "B cell"                      "B cell"
# [1317] "B cell"                      "Megakaryocyte"
# [1319] "CD16+ monocyte"              "CD16+ monocyte"
# [1321] "CD4+ T cell"                 "CD4+ T cell"
# [1323] "CD4+ T cell"                 "CD4+ T cell"
# [1325] "CD4+ T cell"                 "CD4+ T cell"
# [1327] "CD4+ T cell"                 "CD4+ T cell"
# [1329] "CD4+ T cell"                 "CD4+ T cell"
# [1331] "CD4+ T cell"                 "CD4+ T cell"
# [1333] "CD4+ T cell"                 "CD4+ T cell"
# [1335] "CD4+ T cell"                 "CD4+ T cell"
# [1337] "CD4+ T cell"                 "Cytotoxic T cell"
# [1339] "CD4+ T cell"                 "CD4+ T cell"
# [1341] "CD4+ T cell"                 "CD4+ T cell"
# [1343] "CD4+ T cell"                 "CD4+ T cell"
# [1345] "CD4+ T cell"                 "CD4+ T cell"
# [1347] "CD4+ T cell"                 "CD4+ T cell"
# [1349] "CD4+ T cell"                 "Cytotoxic T cell"
# [1351] "CD4+ T cell"                 "CD4+ T cell"
# [1353] "CD4+ T cell"                 "CD4+ T cell"
# [1355] "CD4+ T cell"                 "Cytotoxic T cell"
# [1357] "CD4+ T cell"                 "CD4+ T cell"
# [1359] "CD4+ T cell"                 "CD4+ T cell"
# [1361] "CD4+ T cell"                 "Cytotoxic T cell"
# [1363] "CD4+ T cell"                 "CD4+ T cell"
# [1365] "CD4+ T cell"                 "CD4+ T cell"
# [1367] "CD4+ T cell"                 "CD4+ T cell"
# [1369] "CD4+ T cell"                 "CD4+ T cell"
# [1371] "CD4+ T cell"                 "CD4+ T cell"
# [1373] "CD4+ T cell"                 "CD4+ T cell"
# [1375] "CD4+ T cell"                 "CD4+ T cell"
# [1377] "CD4+ T cell"                 "CD4+ T cell"
# [1379] "CD4+ T cell"                 "CD4+ T cell"
# [1381] "CD4+ T cell"                 "CD4+ T cell"
# [1383] "CD4+ T cell"                 "CD4+ T cell"
# [1385] "CD4+ T cell"                 "CD4+ T cell"
# [1387] "CD4+ T cell"                 "CD4+ T cell"
# [1389] "CD4+ T cell"                 "CD4+ T cell"
# [1391] "CD4+ T cell"                 "CD4+ T cell"
# [1393] "CD4+ T cell"                 "CD4+ T cell"
# [1395] "CD4+ T cell"                 "CD4+ T cell"
# [1397] "CD4+ T cell"                 "CD4+ T cell"
# [1399] "CD4+ T cell"                 "CD4+ T cell"
# [1401] "CD4+ T cell"                 "CD4+ T cell"
# [1403] "CD4+ T cell"                 "CD4+ T cell"
# [1405] "CD4+ T cell"                 "CD4+ T cell"
# [1407] "CD4+ T cell"                 "CD4+ T cell"
# [1409] "CD4+ T cell"                 "B cell"
# [1411] "CD4+ T cell"                 "CD4+ T cell"
# [1413] "CD4+ T cell"                 "CD4+ T cell"
# [1415] "CD4+ T cell"                 "CD4+ T cell"
# [1417] "CD4+ T cell"                 "Cytotoxic T cell"
# [1419] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1421] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1423] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1425] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1427] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1429] "Cytotoxic T cell"            "Cytotoxic T cell"
# [1431] "Cytotoxic T cell"            "Cytotoxic T cell"
# ...
# [4137] "CD4+ T cell"                 "CD14+ monocyte"
# [4139] "B cell"                      "CD4+ T cell"
# [4141] "CD16+ monocyte"              "CD14+ monocyte"
# [4143] "B cell"                      "B cell"
# [4145] "B cell"                      "B cell"
# [4147] "CD4+ T cell"                 "CD14+ monocyte"
# [4149] "CD4+ T cell"                 "CD14+ monocyte"
# [4151] "B cell"                      "CD4+ T cell"
# [4153] "Cytotoxic T cell"            "B cell"
# [4155] "CD4+ T cell"                 "B cell"
# [4157] "CD4+ T cell"                 "CD14+ monocyte"
# [4159] "CD4+ T cell"                 "B cell"
# [4161] "B cell"                      "B cell"
# [4163] "CD14+ monocyte"              "Natural killer cell"
# [4165] "Cytotoxic T cell"            "CD4+ T cell"
# [4167] "CD4+ T cell"                 "CD4+ T cell"
# [4169] "Natural killer cell"         "Cytotoxic T cell"
# [4171] "CD14+ monocyte"              "B cell"
# [4173] "CD4+ T cell"                 "CD4+ T cell"
# [4175] "B cell"                      "B cell"
# [4177] "CD14+ monocyte"              "B cell"
# [4179] "CD14+ monocyte"              "CD4+ T cell"
# [4181] "Cytotoxic T cell"            "CD4+ T cell"
# [4183] "CD4+ T cell"                 "B cell"
# [4185] "B cell"                      "CD4+ T cell"
# [4187] "B cell"                      "CD4+ T cell"
# [4189] "B cell"                      "CD4+ T cell"
# [4191] "B cell"                      "CD4+ T cell"
# [4193] "B cell"                      "CD14+ monocyte"
# [4195] "CD14+ monocyte"              "CD4+ T cell"
# [4197] "CD4+ T cell"                 "Cytotoxic T cell"
# [4199] "CD14+ monocyte"              "Cytotoxic T cell"
# [4201] "B cell"                      "CD14+ monocyte"
# [4203] "CD4+ T cell"                 "Natural killer cell"
# [4205] "Natural killer cell"         "B cell"
# [4207] "B cell"                      "CD4+ T cell"
# [4209] "Natural killer cell"         "B cell"
# [4211] "CD14+ monocyte"              "B cell"
# [4213] "B cell"                      "CD14+ monocyte"
# [4215] "CD16+ monocyte"              "CD16+ monocyte"
# [4217] "CD4+ T cell"                 "B cell"
# [4219] "Cytotoxic T cell"            "B cell"
# [4221] "CD4+ T cell"                 "Natural killer cell"
# [4223] "CD14+ monocyte"              "CD4+ T cell"
# [4225] "CD4+ T cell"                 "CD4+ T cell"
# [4227] "CD4+ T cell"                 "B cell"
# [4229] "Natural killer cell"         "Cytotoxic T cell"
# [4231] "CD4+ T cell"                 "B cell"
# [4233] "Cytotoxic T cell"            "Dendritic cell"
# [4235] "Cytotoxic T cell"            "B cell"
# [4237] "B cell"                      "Cytotoxic T cell"
# [4239] "B cell"                      "B cell"
# [4241] "CD4+ T cell"                 "Cytotoxic T cell"
# [4243] "CD4+ T cell"                 "Megakaryocyte"
# [4245] "Dendritic cell"              "B cell"
# [4247] "CD4+ T cell"                 "CD4+ T cell"
# [4249] "B cell"                      "B cell"
# [4251] "Natural killer cell"         "B cell"
# [4253] "Plasmacytoid dendritic cell" "CD4+ T cell"
# [4255] "B cell"                      "B cell"
# [4257] "CD4+ T cell"                 "B cell"
# [4259] "CD14+ monocyte"              "Cytotoxic T cell"
# [4261] "B cell"                      "B cell"
# [4263] "CD14+ monocyte"              "B cell"
# [4265] "Cytotoxic T cell"            "B cell"
# [4267] "Dendritic cell"              "Cytotoxic T cell"
# [4269] "CD4+ T cell"                 "CD4+ T cell"
# [4271] "Cytotoxic T cell"            "Cytotoxic T cell"
# [4273] "B cell"                      "B cell"
# [4275] "CD14+ monocyte"              "B cell"
# [4277] "B cell"                      "B cell"
# [4279] "CD4+ T cell"                 "CD4+ T cell"
# [4281] "Cytotoxic T cell"            "Natural killer cell"
# [4283] "Cytotoxic T cell"            "CD4+ T cell"
# [4285] "Cytotoxic T cell"            "Natural killer cell"
# [4287] "Cytotoxic T cell"            "B cell"
# [4289] "B cell"                      "CD4+ T cell"
# [4291] "CD4+ T cell"                 "CD4+ T cell"
# [4293] "CD4+ T cell"                 "CD16+ monocyte"
# [4295] "CD4+ T cell"                 "CD4+ T cell"
# [4297] "Cytotoxic T cell"            "CD14+ monocyte"
# [4299] "CD4+ T cell"                 "CD4+ T cell"
# [4301] "CD4+ T cell"                 "CD4+ T cell"
# [4303] "CD4+ T cell"                 "Plasmacytoid dendritic cell"
# [4305] "CD14+ monocyte"              "B cell"
# [4307] "CD4+ T cell"                 "Cytotoxic T cell"
# [4309] "B cell"                      "Natural killer cell"
# [4311] "CD4+ T cell"                 "B cell"
# [4313] "Dendritic cell"              "Cytotoxic T cell"
# [4315] "CD4+ T cell"                 "CD14+ monocyte"
# [4317] "Cytotoxic T cell"            "CD14+ monocyte"
# [4319] "Natural killer cell"         "Cytotoxic T cell"
# [4321] "Cytotoxic T cell"            "B cell"
# [4323] "B cell"                      "CD4+ T cell"
# [4325] "CD4+ T cell"                 "B cell"
# [4327] "B cell"                      "Natural killer cell"
# [4329] "Cytotoxic T cell"            "B cell"
# [4331] "CD4+ T cell"                 "Cytotoxic T cell"
# [4333] "Cytotoxic T cell"            "B cell"
# [4335] "Cytotoxic T cell"            "B cell"
# [4337] "B cell"                      "Natural killer cell"
# [4339] "B cell"                      "CD14+ monocyte"
# [4341] "Natural killer cell"         "B cell"
# [4343] "CD14+ monocyte"              "Cytotoxic T cell"
# [4345] "CD4+ T cell"                 "B cell"
# [4347] "CD4+ T cell"                 "Cytotoxic T cell"
# [4349] "B cell"                      "CD4+ T cell"
# [4351] "Dendritic cell"              "CD14+ monocyte"
# [4353] "Cytotoxic T cell"            "CD4+ T cell"
# [4355] "B cell"                      "B cell"
# [4357] "CD4+ T cell"                 "B cell"
# [4359] "B cell"                      "Cytotoxic T cell"
# [4361] "B cell"                      "CD14+ monocyte"
# [4363] "Cytotoxic T cell"            "Cytotoxic T cell"
# [4365] "Cytotoxic T cell"            "B cell"
# [4367] "CD4+ T cell"                 "Natural killer cell"
# [4369] "CD4+ T cell"                 "B cell"
# [4371] "CD4+ T cell"                 "CD4+ T cell"
# [4373] "CD14+ monocyte"              "B cell"
# [4375] "CD16+ monocyte"              "Cytotoxic T cell"
# [4377] "Cytotoxic T cell"            "CD4+ T cell"
# [4379] "Dendritic cell"              "CD4+ T cell"
# [4381] "Natural killer cell"         "B cell"
# [4383] "CD4+ T cell"                 "CD4+ T cell"
# [4385] "CD4+ T cell"                 "Natural killer cell"
# [4387] "Cytotoxic T cell"            "CD4+ T cell"
# [4389] "Cytotoxic T cell"            "Dendritic cell"
# [4391] "CD4+ T cell"                 "CD14+ monocyte"
# [4393] "Cytotoxic T cell"            "Cytotoxic T cell"
# [4395] "Cytotoxic T cell"            "CD4+ T cell"
# [4397] "Megakaryocyte"               "B cell"
# [4399] "CD4+ T cell"                 "B cell"
# [4401] "CD14+ monocyte"              "Natural killer cell"
# [4403] "CD4+ T cell"                 "CD4+ T cell"
# [4405] "Cytotoxic T cell"            "CD4+ T cell"
# [4407] "B cell"                      "Natural killer cell"
# [4409] "CD14+ monocyte"              "CD4+ T cell"
# [4411] "CD4+ T cell"                 "CD4+ T cell"
# [4413] "Cytotoxic T cell"            "CD4+ T cell"
# [4415] "B cell"                      "CD4+ T cell"
# [4417] "CD16+ monocyte"              "Cytotoxic T cell"
# [4419] "CD4+ T cell"                 "CD4+ T cell"
# [4421] "CD4+ T cell"                 "CD14+ monocyte"
# [4423] "CD14+ monocyte"              "Megakaryocyte"
# [4425] "B cell"                      "CD4+ T cell"
# [4427] "CD4+ T cell"                 "CD14+ monocyte"
# [4429] "B cell"                      "B cell"
# [4431] "B cell"                      "CD4+ T cell"
# [4433] "B cell"                      "CD4+ T cell"
# [4435] "B cell"                      "CD4+ T cell"
# [4437] "CD4+ T cell"                 "Cytotoxic T cell"
# [4439] "B cell"                      "CD4+ T cell"
# [4441] "Megakaryocyte"               "CD14+ monocyte"
# [4443] "B cell"                      "Dendritic cell"
# [4445] "CD14+ monocyte"              "CD4+ T cell"
# [4447] "Natural killer cell"         "CD4+ T cell"
# [4449] "CD4+ T cell"                 "CD14+ monocyte"
# [4451] "Natural killer cell"         "B cell"
# [4453] "CD14+ monocyte"              "CD4+ T cell"
# [4455] "B cell"                      "Cytotoxic T cell"
# [4457] "Cytotoxic T cell"            "CD4+ T cell"
# [4459] "B cell"                      "CD4+ T cell"
# [4461] "CD4+ T cell"                 "B cell"
# [4463] "Cytotoxic T cell"            "B cell"
# [4465] "B cell"                      "CD4+ T cell"
# [4467] "B cell"                      "Dendritic cell"
# [4469] "Cytotoxic T cell"            "Cytotoxic T cell"
# [4471] "CD4+ T cell"                 "CD4+ T cell"
# [4473] "CD4+ T cell"                 "CD4+ T cell"
# [4475] "CD14+ monocyte"              "CD4+ T cell"
# [4477] "Cytotoxic T cell"            "Natural killer cell"
# [4479] "Cytotoxic T cell"            "CD14+ monocyte"
# [4481] "Cytotoxic T cell"            "Cytotoxic T cell"
# [4483] "B cell"                      "CD14+ monocyte"
# [4485] "Cytotoxic T cell"            "Cytotoxic T cell"
# [4487] "B cell"                      "B cell"
# [4489] "CD14+ monocyte"              "Cytotoxic T cell"
# [4491] "B cell"                      "CD4+ T cell"
# [4493] "B cell"                      "CD4+ T cell"
# [4495] "CD14+ monocyte"              "CD14+ monocyte"
# [4497] "Cytotoxic T cell"            "B cell"
# [4499] "Cytotoxic T cell"            "Cytotoxic T cell"
# [4501] "B cell"                      "CD4+ T cell"
# [4503] "Cytotoxic T cell"            "Cytotoxic T cell"
# [4505] "Cytotoxic T cell"            "CD4+ T cell"
# [4507] "B cell"                      "Cytotoxic T cell"
# [4509] "Cytotoxic T cell"            "B cell"
# [4511] "B cell"                      "B cell"
# [4513] "B cell"                      "CD4+ T cell"
# [4515] "CD4+ T cell"                 "CD4+ T cell"
# [4517] "CD14+ monocyte"              "Cytotoxic T cell"
# [4519] "CD4+ T cell"                 "B cell"
# [4521] "B cell"                      "B cell"
# [4523] "Cytotoxic T cell"            "Cytotoxic T cell"
# [4525] "B cell"                      "CD14+ monocyte"
# [4527] "CD4+ T cell"                 "CD14+ monocyte"
# [4529] "Cytotoxic T cell"            "B cell"
# [4531] "Cytotoxic T cell"            "B cell"
# [4533] "CD4+ T cell"                 "B cell"
# [4535] "CD4+ T cell"                 "CD14+ monocyte"
# [4537] "CD14+ monocyte"              "Natural killer cell"
# [4539] "CD16+ monocyte"              "CD4+ T cell"
# [4541] "CD14+ monocyte"              "CD4+ T cell"
# [4543] "CD14+ monocyte"              "CD4+ T cell"
# [4545] "Cytotoxic T cell"            "B cell"
# [4547] "Natural killer cell"         "Cytotoxic T cell"
# [4549] "CD4+ T cell"                 "B cell"
# [4551] "B cell"                      "CD14+ monocyte"
# [4553] "CD4+ T cell"                 "B cell"
# [4555] "CD4+ T cell"                 "B cell"
# [4557] "B cell"                      "CD16+ monocyte"
# [4559] "Cytotoxic T cell"            "CD4+ T cell"
# [4561] "B cell"                      "CD4+ T cell"
# [4563] "Cytotoxic T cell"            "Cytotoxic T cell"
# [4565] "B cell"                      "CD4+ T cell"
# [4567] "CD14+ monocyte"              "CD4+ T cell"
# [4569] "CD14+ monocyte"              "B cell"
# [4571] "B cell"                      "Cytotoxic T cell"
# [4573] "CD14+ monocyte"              "Cytotoxic T cell"
# [4575] "CD16+ monocyte"              "Cytotoxic T cell"
# [4577] "Cytotoxic T cell"            "B cell"
# [4579] "CD4+ T cell"                 "B cell"
# [4581] "CD4+ T cell"                 "Cytotoxic T cell"
# [4583] "B cell"                      "B cell"
# [4585] "CD4+ T cell"                 "Cytotoxic T cell"
# [4587] "Megakaryocyte"               "B cell"
# [4589] "B cell"                      "B cell"
# [4591] "CD4+ T cell"                 "CD4+ T cell"
# [4593] "CD4+ T cell"                 "CD14+ monocyte"
# [4595] "B cell"                      "CD14+ monocyte"
# [4597] "B cell"                      "B cell"
# [4599] "CD14+ monocyte"              "CD4+ T cell"
# [4601] "B cell"                      "CD4+ T cell"
# [4603] "B cell"                      "CD4+ T cell"
# [4605] "Natural killer cell"         "B cell"
# [4607] "CD14+ monocyte"              "CD4+ T cell"
# [4609] "B cell"                      "Megakaryocyte"
# [4611] "B cell"                      "Megakaryocyte"
# [4613] "B cell"                      "B cell"

# %%
for(i in c(1:n_folds)){
    if(!is.null(GeneOrderPath) & !is.null (NumGenes)){
      DataTrain <- Data[as.vector(GenesOrder[c(1:NumGenes),i])+1,Train_Idx[[i]]]
      DataTest <- Data[as.vector(GenesOrder[c(1:NumGenes),i])+1,Test_Idx[[i]]]
    }
    else{
      DataTrain <- Data[,Train_Idx[[i]]]
      DataTest <- Data[,Test_Idx[[i]]]
    }
    
    start_time <- Sys.time()
    cgenes2<-findClassyGenes(DataTrain, data.frame(Annotation = Labels[Train_Idx[[i]]]), "Annotation")
    cgenesA<-cgenes2[['cgenes']]
    grps<-cgenes2[['grps']]
    DataTrain<-as.matrix(DataTrain[cgenesA,])
    xpairs<-ptGetTop(DataTrain, grps, topX=25, sliceSize=5000)
    pdTrain<-query_transform(DataTrain[cgenesA, ], xpairs)
    rf<-sc_makeClassifier(pdTrain[xpairs,], genes=xpairs, groups=grps)
    end_time <- Sys.time()
    Training_Time_singleCellNet[i] <- as.numeric(difftime(end_time,start_time,units = 'secs'))
    
    start_time <- Sys.time()
    DataTest<-query_transform(DataTest[cgenesA,], xpairs)
    classRes <-rf_classPredict(rf, DataTest)
    end_time <- Sys.time()
    Testing_Time_singleCellNet[i] <- as.numeric(difftime(end_time,start_time,units = 'secs'))
    
    True_Labels_singleCellNet[i] <- list(Labels[Test_Idx[[i]]])
    Pred_Labels_singleCellNet[i] <- list((rownames(classRes)[apply(classRes,2,which.max)])[1:length(Test_Idx[[i]])])
  }

  True_Labels_singleCellNet <- as.vector(unlist(True_Labels_singleCellNet))
  Pred_Labels_singleCellNet <- as.vector(unlist(Pred_Labels_singleCellNet))
  Training_Time_singleCellNet <- as.vector(unlist(Training_Time_singleCellNet))
  Testing_Time_singleCellNet <- as.vector(unlist(Testing_Time_singleCellNet))
# Out:
# Done testing
# Error in genes[[i]]: subscript out of bounds
# Traceback:

# %%
setwd(OutputDir)
  
if(!is.null(GeneOrderPath) & !is.null (NumGenes)){
write.csv(True_Labels_singleCellNet,paste('singleCellNet_',NumGenes,'_True_Labels.csv', sep = ''),row.names = FALSE)
write.csv(Pred_Labels_singleCellNet,paste('singleCellNet_',NumGenes,'_Pred_Labels.csv', sep = ''),row.names = FALSE)
write.csv(Training_Time_singleCellNet,paste('singleCellNet_',NumGenes,'_Training_Time.csv', sep = ''),row.names = FALSE)
write.csv(Testing_Time_singleCellNet,paste('singleCellNet_',NumGenes,'_Testing_Time.csv', sep = ''),row.names = FALSE)
}
else{
write.csv(True_Labels_singleCellNet,'singleCellNet_True_Labels.csv',row.names = FALSE)
write.csv(Pred_Labels_singleCellNet,'singleCellNet_Pred_Labels.csv',row.names = FALSE)
write.csv(Training_Time_singleCellNet,'singleCellNet_Training_Time.csv',row.names = FALSE)
write.csv(Testing_Time_singleCellNet,'singleCellNet_Testing_Time.csv',row.names = FALSE)
}
